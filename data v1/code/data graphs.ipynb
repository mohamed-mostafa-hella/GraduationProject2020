# %% [markdown]
# # this file is some analyses on data to show some paternes is it

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

aceleracaoLinear = pd.read_csv("NEW_aceleracaoLinear_terra.csv")
aceleracaoLinear = aceleracaoLinear.drop(['Unnamed: 0','timestamp','val','uptimeNanos'] ,axis=1)
aceleracaoLinear.head(30)
# Out:
#            x         y         z
# 0  -0.161602  0.120174 -0.209893
# 1  -0.122628  0.315638 -0.380996
# 2  -0.178777  0.330181 -0.360696
# 3   0.016043  0.038759 -0.278204
# 4   0.141716 -0.162492 -0.049796
# 5   0.094701 -0.208684  0.060976
# 6  -0.093779  0.126911 -0.190100
# 7  -0.204955  0.198113 -0.337521
# 8  -0.070380  0.081215 -0.273695
# 9   0.047234 -0.219240 -0.018233
# 10  0.085305 -0.322752 -0.106739
# 11  0.021936  0.010843 -0.087922
# 12 -0.045644  0.090066 -0.252980
# 13 -0.075021  0.206444 -0.162645
# 14  0.048585 -0.033574 -0.074131
# 15  0.036605 -0.114658 -0.063715
# 16  0.060567  0.010338 -0.145992
# 17  0.017414  0.097962 -0.271338
# 18 -0.086638  0.072514 -0.178029
# 19  0.012566 -0.027984 -0.189463
# 20  0.031955 -0.051754 -0.056780
# 21  0.068730 -0.151033 -0.126053
# 22 -0.035640  0.088522 -0.098576
# 23 -0.075969  0.010104 -0.184857
# 24 -0.013879  0.001805 -0.070044
# 25 -0.030778 -0.074656 -0.078585
# 26 -0.000541 -0.031905 -0.150921
# ...

# %%
arr = np.array(aceleracaoLinear)
arr = arr[72:327, :]
plt.plot(arr)
plt.title('evento_nao_agressivo')
plt.show()

# %%
arr1 = np.array(aceleracaoLinear)
arr1 = arr1[1498:1701, :]
plt.plot(arr1)
plt.title('evento_nao_agressivo')
plt.show()

# %%
arr1 = np.array(aceleracaoLinear)
arr1 = arr1[887:1243, :]
plt.plot(arr1)
plt.title('curva_direita_agressiva')
plt.show()

# %%
arr1 = np.array(aceleracaoLinear)
arr1 = arr1[4758:5063, :]
plt.plot(arr1)
plt.title('curva_direita_agressiva')
plt.show()

# %%
arr1 = np.array(aceleracaoLinear)
arr1 = arr1[0:70, :]
plt.plot(arr1)
plt.title('normal')
plt.show()

# %%
arr1 = np.array(aceleracaoLinear)
arr1 = arr1[38121:38477, :]
plt.plot(arr1)
plt.title('curva_esquerda_agressiva')
plt.show()

# %%
arr1 = np.array(aceleracaoLinear)
arr1 = arr1[55287:55643, :]
plt.plot(arr1)
plt.title('curva_esquerda_agressiva')
plt.show()
